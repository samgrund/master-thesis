# %%
import matplotlib.pyplot as plt
import numpy as np
import sattools.sattools as st

# %%
satname = "LEMUR 1"
tle = """0 LEMUR 1
1 40044U 14033AL  15013.74135905  .00002013  00000-0  31503-3 0  6119
2 40044 097.9584 269.2923 0059425 258.2447 101.2095 14.72707190 30443"""
qth = (37.771034, 122.413815, 7)  # lat (N), long (W), alt (meters)

# %%
tstamps = st.minute_timestamps(10)

# %%
fig, passes = st.get_visible(tle, qth, tstamps, satname=satname)
# Out:
# /Users/samuel/Library/CloudStorage/OneDrive-Aarhusuniversitet/Speciale/SatelliteWork/Illuminated_Observations/sattools/sattools.py:102: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks(), rotation=45)

# %%
fig
